# %% [markdown]
# # Es 1
# Di seguito i risultati del campionamento del prezzo fatto col data blocking
#
# #### Call, formula diretta

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math

x,y,error = np.loadtxt("es1/1formulaC.txt", usecols=(0,1,2), delimiter="  ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('Call')
plt.grid(True)

# %% [markdown]
# #### Put, formula diretta

# %%
x,y,error = np.loadtxt("es1/1formulaP.txt", usecols=(0,1,2), delimiter="  ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('Put')
plt.grid(True)

# %% [markdown]
# #### Call, formula discreta

# %%
x,y,error = np.loadtxt("es1/1formulaCDiscr.txt", usecols=(0,1,2), delimiter="  ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('call')
plt.grid(True)

# %% [markdown]
# #### Put, formula discreta

# %%
x,y,error = np.loadtxt("es1/1formulaPDiscr.txt", usecols=(0,1,2), delimiter="  ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('Put')
plt.grid(True)
