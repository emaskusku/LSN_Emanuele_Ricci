# %% [markdown]
# # Es 10.2

# %% [markdown]
# Per questo compito ho usato 4 core e la tecnica $Continents$. Nel caso delle città disposte su una circonferenza non ho notato un aumento della velocità di convergenza, mentre per quello delle città poste casualmente invece sì, anche se lieve. Avrei voluto vedere un miglioramento più consistente ma visto che comunque il codice converge in 80-90 generazioni è difficile apprezzare un incremento significativo.

# %% [markdown]
# ## 32 città sulla circonferenza

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math


x,y = np.loadtxt("cities_0.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %% [markdown]
# #### Lunghezza del percorso più breve per ogni generazione

# %%
y = np.loadtxt("bestpathgen_0.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgen_1.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgen_2.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgen_3.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.show()

# %% [markdown]
# #### Media della metà delle lunghezze più corte della generazione

# %%
y = np.loadtxt("avebestpath_0.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpath_1.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpath_2.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpath_3.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.show()

# %% [markdown]
# #### Percorso ottimale trovato

# %%
x,y = np.loadtxt("bestpath_0.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')

plt.figure()
x,y = np.loadtxt("bestpath_1.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()

x,y = np.loadtxt("bestpath_2.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')

plt.figure()
x,y = np.loadtxt("bestpath_3.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %% [markdown]
# ## 32 città randomiche

# %%
x,y = np.loadtxt("citiesrandom_0.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='.')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()
x,y = np.loadtxt("citiesrandom_1.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='.')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()
x,y = np.loadtxt("citiesrandom_2.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='.')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()
x,y = np.loadtxt("citiesrandom_3.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='.')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %% [markdown]
# #### Lunghezza del percorso più breve per ogni generazione

# %%
y = np.loadtxt("bestpathgenrandom_0.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgenrandom_1.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgenrandom_2.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("bestpathgenrandom_3.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.show()

# %% [markdown]
# #### Media della metà delle lunghezze più corte della generazione

# %%
y = np.loadtxt("avebestpathrandom_0.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpathrandom_1.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpathrandom_2.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.figure()
y = np.loadtxt("avebestpathrandom_3.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$<|L|>^2$')
plt.xlabel(f'generations')
plt.show()

# %% [markdown]
# #### Percorso ottimale trovato

# %%
x,y = np.loadtxt("bestpathrandom_0.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()

x,y = np.loadtxt("bestpathrandom_1.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()

x,y = np.loadtxt("bestpathrandom_2.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.figure()

x,y = np.loadtxt("bestpathrandom_3.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()
