# %% [markdown]
# # Es 10.1

# %% [markdown]
# Ho usato le mutazioni del GA.
# Per risolvere il problema sono partito da una temperatura T=200, facendola scendere del 7% ogni 1000 generazioni delle 100000 che ho usato e che reputo sufficienti.

# %% [markdown]
# ## 32 città randomiche

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math


x,y = np.loadtxt("cities.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.plot(x,y,linestyle="",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %%
y = np.loadtxt("path.txt", usecols=(0), delimiter=" ", unpack='true')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.plot(y,marker='.')
plt.figure()
y = np.loadtxt("temp.txt", usecols=(0), delimiter=" ", unpack='true')
plt.ylabel(f'$T$')
plt.xlabel(f'generations')
plt.plot(y,linestyle="",marker='.')
plt.show()

# %% [markdown]
# #### Miglior percorso

# %%
x,y = np.loadtxt("bestpath.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %% [markdown]
# #### Rating di accettazione del metropolis

# %%
x,y,z = np.loadtxt("metropolisAccTot.txt", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.plot(z,x/y,linestyle="",marker='o')
plt.ylabel(f'Acc/Tot')
plt.xlabel(f'T')
plt.show()

# %% [markdown]
# # Percorso random

# %%
x,y = np.loadtxt("citiesrandom.txt", usecols=(0,1), delimiter=" ", unpack='true')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.plot(x,y,linestyle="",marker='o')
plt.show()

# %%
y = np.loadtxt("pathrandom.txt", usecols=(0), delimiter=" ", unpack='true')
plt.ylabel(f'$|L|^2$')
plt.xlabel(f'generations')
plt.plot(y,marker='.')
plt.figure()
y = np.loadtxt("temprandom.txt", usecols=(0), delimiter=" ", unpack='true')
plt.plot(y,linestyle="",marker='.')
plt.ylabel(f'$T$')
plt.xlabel(f'generations')
plt.show()

# %% [markdown]
# #### Miglior percorso

# %%
x,y = np.loadtxt("bestpathrandom.txt", usecols=(0,1), delimiter=" ", unpack='true')
width1 = 10
height1 = 10
width_height_1 = (width1, height1)
plt.figure(figsize=width_height_1)
plt.plot(x,y,linestyle="dashed",marker='o')
plt.ylabel(f'y')
plt.xlabel(f'x')
plt.show()

# %% [markdown]
# #### Rating di accettazione del metropolis

# %%
x,y,z = np.loadtxt("metropolisAccTotrandom.txt", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.ylabel(f'Acc/Tot')
plt.plot(z,x/y,linestyle="",marker='o')
plt.xlabel(f'T')
plt.show()
