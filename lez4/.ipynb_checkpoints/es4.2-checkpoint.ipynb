# %% [markdown]
# # Es 2

# %% [markdown]
# Dopo le necessarie modifiche al codice è stato possibile procedere con la misurazione dei valori richiesti con la media a blocchi. Come al solito 100 blocchi

# %% [markdown]
# ### Energia cinetica

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math

x,y,error = np.loadtxt("MolecularDynamics_NVE/ave_ekin.out", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#values')
plt.ylabel('Ekin [j]')
plt.grid(True)

# %% [markdown]
# ### Energia potenziale

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math

x,y,error = np.loadtxt("MolecularDynamics_NVE/ave_epot.out", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#values')
plt.ylabel('Epot [j]')
plt.grid(True)

# %% [markdown]
# ### Energia totale

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math

x,y,error = np.loadtxt("MolecularDynamics_NVE/ave_etot.out", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#values')
plt.ylabel('Etot [j]')
plt.grid(True)

# %% [markdown]
# ### Temperatura

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math

x,y,error = np.loadtxt("MolecularDynamics_NVE/ave_temp.out", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(x,y,yerr=error)
plt.xlabel('#values')
plt.ylabel('T [k]')
plt.grid(True)
